# %% [markdown]
# <a href="https://colab.research.google.com/github/denizyy/ADM-HW3/blob/main/HW3_(RQ1_2_3_%26_AQ).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 3 - Master's Degrees from all over!
#
# **Knowledge!**
#
# Nowadays, society expects everyone, especially you, to have a decent level of knowledge from a relatively wide range of topics. To do so, as you are all doing here, most students choose, after finishing their undergraduate studies, to keep on studying. The natural next step is the Master's Degree!
# You will be working with a [webpage](https://www.findamasters.com) that provides information and evalutation on many of these master's degrees in many universities worldwide.

# %% [markdown]
# # VERY VERY IMPORTANT
# 1. **!!! Read the entire homework before coding anything!!!**
# 2. *My solution is not better than yours, and yours is not better than mine*. In any data analysis task, there **is no** unique way to answer. For this reason, it is crucial (**necessary and mandatory**) that you describe any single decision you take and all your steps.
# 3. Once solving an exercise, comments about the obtained results are **mandatory**. We are not always explicit about where to focus your comments, but we will always want brief sentences about your discoveries.
# 4. We encourage using chatGPT (Bard, Bing, or any other Large Language Models (LLM) chatbot tool) as allies to help you solve your homework, and we were hoping you could learn how to use them properly. However, **using such tools when not explicitly allowed will be considered plagiarism and strictly prohibited**.
#
# Now that it is all well settled, let's get on with it!

# %% [markdown]
# ## 1. Data collection
#
# For this homework, there is no provided dataset. Instead, you have to build your own. Your search engine will run on text documents. So, here
# we detail the procedure to follow for the data collection. We strongly suggest you work on different modules when implementing the required functions. For example, you may have a ```crawler.py``` module, a ```parser.py``` module, and a ```engine.py``` module: this is a good practice that improves readability in reporting and efficiency in deploying the code. Be careful; you are likely dealing with exceptions and other possible issues!

# %%
import requests
from bs4 import BeautifulSoup
import os # To create folder
import time
from tqdm.notebook import tqdm
import pandas as pd
import crawler

# %% [markdown]
# ### 1.1. Get the list of master's degree courses
#
# We start with the list of courses to include in your corpus of documents. In particular, we focus on web scrapping the [MSc Degrees](https://www.findamasters.com/masters-degrees/msc-degrees/). Next, we want you to **collect the URL** associated with each site in the list from the previously collected list.
# The list is long and split into many pages. Therefore, we ask you to retrieve only the URLs of the places listed in **the first 400 pages** (each page has 15 courses, so you will end up with 6000 unique master's degree URLs).
#
# The output of this step is a `.txt` file whose single line corresponds to the master's URL.

# %%
url = 'https://www.findamasters.com/masters-degrees/msc-degrees/'
page_urls = [] # list containing all the master's degree URLs

# Get the master's degree URL for all 400 pages
for page_number in tqdm(range(1, 401), desc="Extracting URLs", unit="Page"):

   # URL of the page
    page_url = f"{url}?PG={page_number}"

    try:
        # append to the list the 15 courses of each page
        page_urls.extend(crawler.extract_MSc(page_url))


    except requests.exceptions.RequestException as e:
        print(f"Error in web scraping: {e}")
# Out:
# Extracting URLs:   0%|          | 0/400 [00:00<?, ?Page/s]
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=42
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=43
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=44
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=45
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=46
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=47
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=48
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=49
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=50
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=51
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=52
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=53
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=54
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=55
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=56
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=57
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=58
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=59
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=60
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=61
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=62
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=63
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=64
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=65
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=66
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=67
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=68
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=69
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=70
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=71
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=72
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=73
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=74
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=75
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=76
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=77
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=78
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=79
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=80
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=81
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=82
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=83
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=84
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=85
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=86
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=87
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=88
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=89
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=90
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=91
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=92
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=93
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=94
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=95
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=96
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=97
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=98
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=99
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=100
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=101
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=102
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=103
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=104
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=105
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=106
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=107
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=108
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=109
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=110
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=111
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=112
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=113
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=114
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=115
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=116
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=117
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=118
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=119
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=120
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=121
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=122
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=123
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=124
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=125
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=126
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=127
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=128
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=129
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=130
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=131
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=132
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=133
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=134
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=135
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=136
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=137
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=138
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=139
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=140
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=141
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=142
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=143
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=144
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=145
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=146
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=147
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=148
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=149
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=150
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=151
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=152
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=153
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=154
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=155
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=156
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=157
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=158
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=159
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=160
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=161
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=162
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=163
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=164
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=165
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=166
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=167
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=168
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=169
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=170
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=171
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=172
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=173
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=174
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=175
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=176
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=177
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=178
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=179
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=180
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=181
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=182
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=183
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=184
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=185
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=186
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=187
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=188
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=189
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=190
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=191
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=192
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=193
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=194
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=195
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=196
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=197
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=198
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=199
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=200
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=201
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=202
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=203
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=204
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=205
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=206
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=207
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=208
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=209
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=210
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=211
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=212
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=213
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=214
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=215
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=216
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=217
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=218
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=219
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=220
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=221
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=222
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=223
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=224
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=225
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=226
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=227
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=228
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=229
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=230
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=231
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=232
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=233
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=234
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=235
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=236
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=237
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=238
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=239
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=240
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=241
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=242
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=243
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=244
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=245
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=246
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=247
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=248
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=249
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=250
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=251
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=252
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=253
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=254
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=255
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=256
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=257
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=258
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=259
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=260
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=261
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=262
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=263
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=264
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=265
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=266
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=267
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=268
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=269
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=270
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=271
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=272
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=273
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=274
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=275
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=276
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=277
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=278
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=279
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=280
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=281
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=282
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=283
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=284
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=285
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=286
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=287
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=288
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=289
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=290
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=291
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=292
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=293
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=294
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=295
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=296
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=297
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=298
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=299
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=300
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=301
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=302
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=303
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=304
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=305
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=306
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=307
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=308
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=309
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=310
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=311
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=312
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=313
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=314
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=315
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=316
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=317
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=318
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=319
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=320
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=321
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=322
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=323
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=324
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=325
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=326
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=327
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=328
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=329
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=330
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=331
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=332
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=333
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=334
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=335
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=336
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=337
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=338
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=339
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=340
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=341
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=342
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=343
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=344
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=345
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=346
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=347
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=348
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=349
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=350
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=351
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=352
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=353
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=354
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=355
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=356
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=357
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=358
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=359
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=360
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=361
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=362
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=363
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=364
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=365
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=366
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=367
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=368
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=369
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=370
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=371
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=372
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=373
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=374
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=375
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=376
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=377
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=378
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=379
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=380
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=381
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=382
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=383
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=384
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=385
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=386
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=387
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=388
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=389
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=390
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=391
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=392
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=393
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=394
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=395
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=396
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=397
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=398
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=399
# Error in web scraping: 429 Client Error: Too Many Requests for url: https://www.findamasters.com/masters-degrees/msc-degrees/?PG=400

# %%
# Here we save the .txt file
with open('master_degree_urls.txt','w') as file:
    for url in page_urls:
        file.write(url + '\n')

# %% [markdown]
# ### 1.2. Crawl master's degree pages
#
# Once you get all the URLs in the first 400 pages of the list, you:
#
# 1. Download the HTML corresponding to each of the collected URLs.
# 2. After you collect a single page, immediately save its `HTML` in a file. In this way, if your program stops for any reason, you will not lose the data collected up to the stopping point.
# 3. Organize the downloaded `HTML` pages into folders. Each folder will contain the `HTML` of the courses on page 1, page 2, ... of the list of master's programs.
#
# __Tip__: Due to the large number of pages you should download, you can use some methods that can help you shorten the time. If you employed a particular process or approach, kindly describe it.

# %%
# Here we create 400 folders on our computer and save 15 html files in each one of them

# Open the txt file and retrieve each URL
with open('/content/master_degree_urls.txt', 'r') as file:
    urls = [line.strip() for line in file]


# Initialize variables to save 15 HTML files in each folder
i = 0
number = 1

for url in tqdm(urls, desc="Downloading HTML Files", unit="URL"):

    # To each URL, we need to add the base root of the website
    url = 'https://www.findamasters.com' + url

    # if I have saved 15 files, change folder
    if i == 15:
        i = 0
        number += 1

    folder_path = f'/Users/Deniz/Desktop/ADM/HW3/Page{number}'

    # Ensure the folder exists, create it if it doesn't
    os.makedirs(folder_path, exist_ok=True)

    # Get the content of the website
    r = requests.get(url)
    content = r.content

    time.sleep(1)  # Add a delay of 1 second between requests to avoid getting banned

    # Create a suitable name
    url = f'course_{i}'

    # Combine the folder_path and file_name to get the full path where to save the file
    file_path = os.path.join(folder_path, url)

    with open(f'{file_path}.html', 'wb') as html_file:
        html_file.write(content)

    i += 1

    time.sleep(1) # Add a delay of 1 second between requests to avoid getting banned
# Out:
# Downloading HTML Files:   0%|          | 0/720 [00:00<?, ?URL/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-74b44174aa79> in <cell line: 12>()
#      42     i += 1
#      43
# ---> 44     time.sleep(1) # Add a delay of 1 second between requests to avoid getting banned
#
# KeyboardInterrupt:

# %% [markdown]
# ### 1.3 Parse downloaded pages
#
# At this point, you should have all the HTML documents about the master's degree of interest, and you can start to extract specific information. The list of the information we desire for each course and their format is as follows:
#
# 1. Course Name (to save as ```courseName```): string;
# 2. University (to save as ```universityName```): string;
# 3. Faculty (to save as ```facultyName```): string
# 4. Full or Part Time (to save as ```isItFullTime```): string;
# 5. Short Description (to save as ```description```): string;
# 6. Start Date (to save as ```startDate```): string;
# 7. Fees (to save as ```fees```): string;
# 8. Modality (to save as ```modality```):string;
# 9. Duration (to save as ```duration```):string;
# 10. City (to save as ```city```): string;
# 11. Country (to save as ```country```): string;
# 12. Presence or online modality (to save as ```administration```): string;
# 13. Link to the page (to save as ```url```): string.
#
# <p align="center">
# <img src="img/example.jpeg" width = 1000>
# </p>
# This are the first rows of the scraped dataset:
#
# <div style="overflow-x:auto;">
# <table>
# <thead>
#   <tr>
#     <th>index</th>
#     <th>courseName</th>
#     <th>universityName</th>
#     <th>facultyName</th>
#     <th>isItFullTime</th>
#     <th>description</th>
#     <th>startDate</th>
#     <th>fees</th>
#     <th>modality</th>
#     <th>duration</th>
#     <th>city</th>
#     <th>country</th>
#     <th>administration</th>
#     <th>url</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td>0</td>
#     <td> Accounting and Finance - MSc</td>
#     <td>University of Leeds</td>
#     <td>Leeds University Business School</td>
#     <td>Full time</td>
#     <td>Businesses and governments rely on [...].</td>
#     <td>September</td>
#     <td>UK: £18,000 (Total) International: £34,750 (Total)</td>
#     <td>MSc</td>
#     <td>1 year full time</td>
#     <td>Leeds</td>
#     <td>United Kingdom</td>
#     <td>On Campus</td>
#     <td><a href="https://www.findamasters.com/masters-degrees/course/accounting-and-finance-msc/?i321d3232c3891">Link</a></td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td> Accounting, Accountability & Financial Management MSc</td>
#     <td>King’s College London</td>
#     <td>King’s Business School</td>
#     <td>Full time</td>
#     <td>Our Accounting, Accountability & Financial Management MSc course will provide [...].</td>
#     <td>September</td>
#     <td>Please see the university website for further information on fees for this course.</td>
#     <td>MSc</td>
#     <td>1 year FT</td>
#     <td>London</td>
#     <td>United Kingdom</td>
#     <td>On Campus</td>
#     <td><a href="https://www.findamasters.com/masters-degrees/course/accounting-accountability-and-financial-management-msc/?i132d7816c25522">Link</a></td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td> Accounting, Financial Management and Digital Business - MSc</td>
#     <td>University of Reading</td>
#     <td>Henley Business School</td>
#     <td>Full time</td>
#     <td>Embark on a professional accounting career [...].</td>
#     <td>September</td>
#     <td>Please see the university website for further information on fees for this course.</td>
#     <td>MSc</td>
#     <td>1 year full time</td>
#     <td>Reading</td>
#     <td>United Kingdom</td>
#     <td>On Campus</td>
#     <td><a href="https://www.findamasters.com/masters-degrees/course/accounting-financial-management-and-digital-business-msc/?i345d4286c351">Link</a></td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td> Addictions MSc</td>
#     <td>King’s College London</td>
#     <td>Institute of Psychiatry, Psychology and Neuroscience</td>
#     <td>Full time</td>
#     <td>Join us for an online session for prospective [...].</td>
#     <td>September</td>
#     <td>Please see the university website for further information on fees for this course.</td>
#     <td>MSc</td>
#     <td>One year FT</td>
#     <td>London</td>
#     <td>United Kingdom</td>
#     <td>On Campus</td>
#     <td><a href="https://www.findamasters.com/masters-degrees/course/addictions-msc/?i132d4318c27100">Link</a></td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td> Advanced Chemical Engineering - MSc</td>
#     <td>University of Leeds</td>
#     <td>School of Chemical and Process Engineering</td>
#     <td>Full time</td>
#     <td>The Advanced Chemical Engineering MSc at Leeds [...].</td>
#     <td>September</td>
#     <td>UK: £13,750 (Total) International: £31,000 (Total)</td>
#     <td>MSc</td>
#     <td>1 year full time</td>
#     <td>Leeds</td>
#     <td>United Kingdom</td>
#     <td>On Campus</td>
#   </tr>
#   <!-- Add more rows here as needed -->
# </tbody>
# </table>
# </div>
#
#
# For each master's degree, you create a `course_i.tsv` file of this structure:
#
# ```
# courseName \t universityName \t  ... \t url
# ```
#
# If an information is missing, you just leave it as an empty string.

# %%
# Inizialize dataframe
columns = ['courseName', 'universityName','facultyName','isItFullTime','description','startDate','fees','modality','duration','city','country','adminsitration','url']
data = []

# %%
# For all the folders
for number in tqdm(range(1,401), desc= "Creating tsv files", unit="URL"):

    # Path of folder
    folder_path = f'/Users/Francesco/Desktop/ADM/HW3/Page{number}'

    # List of files in directory
    file_list = os.listdir(folder_path)
    file_list = [f for f in file_list if f.endswith('.html')] # On Mac there is a file called .DS_store, we don't want it

    # For each file
    for i,file_name in enumerate(file_list):

        # Full path of file (folder path + file path)
        file_path = os.path.join(folder_path, file_name)

        # Read file
        with open(file_path, 'rb') as file:
            file_content = file.read()

        # Get infos of the page into a list
        content = crawler.extract_MSc_content(file_content)

        # Create tsv file using name of the course
        file_name = f'course_{i}'
        file_path = os.path.join(folder_path, file_name)

        with open(f'{file_path}.tsv','w') as tsvfile:
            tsvfile.write(f'{content[0]} \t {content[1]} \t {content[2]} \t {content[3]} \t {content[4]} \t {content[5]} \t {content[6]} \t {content[7]} \t {content[8]} \t {content[9]} \t {content[10]} \t {content[11]} \t {content[12]}')

# %%
# Merging the .tsv files into one df
for number in tqdm(range(1,401), desc= "Merging tsv files", unit="URL"):

    # Path of folder
    folder_path = f'/Users/Francesco/Desktop/ADM/HW3/Page{number}'

    # List of files in directory
    file_list = os.listdir(folder_path)
    file_list = [f for f in file_list if f.endswith('.tsv')] # On Mac there is a file called .DS_store, we don't want it

    # For each file
    for file_name in file_list:

        # Full path of file
        file_path = os.path.join(folder_path, file_name)

        # Read the .tsv file
        df = pd.read_csv(file_path, sep='\t',names=columns)

        # Append df into a list
        data.append(df)

# Concat all the df into one
merged_df = pd.concat(data, ignore_index=True)

# Download df
merged_df.to_csv('/Users/Francesco/Desktop/ADM/HW3/df.csv', index=False)

# %% [markdown]
# ## 2. Search Engine
#
# Now, we want to create two different Search Engines that, given as input a query, return the courses that match the query.

# %%
import pandas as pd
df = pd.read_csv('/content/df.csv')

# %%
df.head()
# Out:
#                                           courseName  \
# 0                      Accounting and Finance - MSc
# 1                                    Addictions MSc
# 2  Accounting, Financial Management and Digital B...
# 3  Agricultural, Environmental and Resource Econo...
# 4  Applied Economics (Banking and Financial Marke...
#
#              universityName  \
# 0      University of Leeds
# 1    King’s College London
# 2    University of Reading
# 3   University of Helsinki
# 4       University of Bath
#
#                                          facultyName             isItFullTime  \
# 0                  Leeds University Business School                Full time
# 1   Institute of Psychiatry, Psychology and Neuro...   Full time & Part time
# 2                            Henley Business School                Full time
# 3           International Masters Degree Programmes                Full time
# 4                         University of Bath Online                Part time
#
#                                          description             startDate  \
# 0   Businesses and governments rely on sound fina...            September
# 1   Join us for an online session for prospective...            September
# 2   Embark on a professional accounting career wi...            September
# 3   Goal of the pro­grammeAre you looking forward...            September
# 4   From political uncertainty to finance and rec...   September, January
#
#                                                 fees modality  \
# 0   UK: £18,000 (Total) International: £34,750 (T...     MSc
# 1   Please see the university website for further...     MSc
# 2   Please see the university website for further...     MSc
# 3   Tuition fee per year (non-EU/EEA students): 1...     MSc
# 4   Cost per 10 credits £722* (10% alumni discoun...     MSc
#
#                            duration        city           country  \
# 0                 1 year full time       Leeds    United Kingdom
# 1                      One year FT      London    United Kingdom
# 2                 1 year full time     Reading    United Kingdom
# 3                          2 years    Helsinki           Finland
# 4   2 years and 6 months full time        Bath    United Kingdom
#
#   adminsitration                                                url
# 0     On Campus    https://www.findamasters.com/masters-degrees/...
# 1     On Campus    https://www.findamasters.com/masters-degrees/...
# 2     On Campus    https://www.findamasters.com/masters-degrees/...
# 3     On Campus    https://www.findamasters.com/masters-degrees/...
# 4        Online    https://www.findamasters.com/masters-degrees/...

# %% [markdown]
# ### 2.0 Preprocessing
#
# ### 2.0.0)  Preprocessing the text
#
# First, you must pre-process all the information collected for each MSc by:
#
# 1. Removing stopwords
# 2. Removing punctuation
# 3. Stemming
# 4. Anything else you think it's needed
#
# For this purpose, you can use the [`nltk library](https://www.nltk.org/).

# %%
#I got error indicates that the NLTK library is unable to find the 'punkt' resource, which is necessary for tokenization. So I added this code cell.
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from nltk.stem import *
import nltk
from nltk.corpus import stopwords
#create the instance of the stemmer
stemmer = PorterStemmer()
#download the nltk stopwords
nltk.download('stopwords')
#make sure that they are english words
lst_stopwords = stopwords.words('english')
#drop potential null values from the description column
df = df.dropna(subset=['description'])
#uses apply method with list comprehension to tokenize each row and stem each word as well as filter them on alphanumeric and prevent stopwords
df['descr_clean'] = df.description.apply(lambda row: [stemmer.stem(word) for word in nltk.word_tokenize(row) if not word in lst_stopwords and word.isalnum()])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import pandas as pd
import re

df['fees'] = df['fees'].apply(lambda row: str(row).replace(',', ''))

def extract_largest_amount(text):
    # Define the regular expression pattern
    # This pattern looks for amounts with or without a space before/after the currency symbol
    # It only looks for dollars, pounds, and euros
    currency_pattern = r'(\$\s?\d+(?:\.\d+)?|\d+(?:\.\d+)?\s?€|\d+(?:\.\d+)?\s?£|£\s?\d+(?:\.\d+)?|\d+(?:\.\d+)?\s?\$|\d+(?:\.\d+)?\s?€|\d+(?:\.\d+)?\s?£|\£\s?\d+(?:\.\d+)?|\€\s?\d+(?:\.\d+)?|\d+(?:\.\d+)?\s?\€)'

    # Find all matches
    matches = re.findall(currency_pattern, text)

    # Convert matches to numeric values for comparison
    amounts = []
    for match in matches:
        # Remove currency symbols and non-numeric characters, convert to float
        amount = float(re.sub(r'[^\d.]', '', match))
        amounts.append((amount, match))

    # Find the largest amount
    if amounts:
        return max(amounts)[1]
    else:
        return None

# Apply the function to the DataFrame
df['cleaned_fees'] = df['fees'].apply(extract_largest_amount)

# %%
#the number of numerical values that did not catch out regex
num_values_cleaned_fees = df['cleaned_fees'].notna().sum()
num_values_fees = len(df[df['fees'].astype(str).str.contains(r'\d')])
print(f"There are {num_values_fees} of rows that have some digits, my algorithm found {num_values_cleaned_fees} rows after cleaning fees")
# Out:
# There are 1627 of rows that have some digits, my algorithm found 1217 rows after cleaning fees

# %%
not_caught_values = df[df['fees'].astype(str).str.contains(r'\d') & df['cleaned_fees'].isna()]
not_caught_values.head()
#they are other currencies like ISK, that is quite difficult to catch
# Out:
#                                             courseName  \
# 58                      Coastal and Marine Management
# 87                            Doctor of Public Health
# 98         Engineering Business Management online MSc
# 185  Master in Global Logistics and Supply Chain Ma...
# 346                      MSc International Management
#
#                               universityName  \
# 58     University Centre of the West Fjords
# 87                       Harvard University
# 98                       University of Bath
# 185       Kuehne Logistics University - KLU
# 346   University of Nottingham Ningbo China
#
#                                      facultyName             isItFullTime  \
# 58                              Masters Program    Full time & Part time
# 87    Harvard T.H. Chan School of Public Health                Full time
# 98                    University of Bath Online                Part time
# 185                     Business and Management    Full time & Part time
# 346               International Masters Courses                Full time
#
#                                            description             startDate  \
# 58    Coastal and Marine Management http://www.uw.i...            September
# 87    ﻿Learn to translate knowledge into powerful r...            Any Month
# 98    Develop an in-depth understanding of engineer...   September, January
# 185   Our MSc in Global Logistics and Supply Chain ...           See Course
# 346   The MSc International Management programme fu...            September
#
#                                                   fees  \
# 58    The annual fee is ISK 150.000 for students fr...
# 87    All students admitted to the DrPH program inc...
# 98    The Engineering Business Management online MS...
# 185   EUR 7390.00 per semester (Standard and Part-t...
# 346   Domestic course fees: 100000 RMB / year Inter...
#
#                          modality                          duration  \
# 58                           MSc                         18 months
# 87    MSc, Prof Doctorate, Other                 3 years full time
# 98                           MSc    2 years and 3 months full time
# 185                          MSc                           2 Years
# 346                          MSc               12 months full time
#
#              city           country adminsitration  \
# 58    Isafjorour           Iceland
# 87        Boston               USA      On Campus
# 98          Bath    United Kingdom         Online
# 185      Hamburg           Germany      On Campus
# 346       Ningbo             China      On Campus
#
#                                                    url  \
# 58    https://www.findamasters.com/masters-degrees/...
# 87    https://www.findamasters.com/masters-degrees/...
# 98    https://www.findamasters.com/masters-degrees/...
# 185   https://www.findamasters.com/masters-degrees/...
# 346   https://www.findamasters.com/masters-degrees/...
#
#                                            descr_clean cleaned_fees
# 58   [coastal, marin, manag, http, intern, interdis...         None
# 87   [translat, knowledg, power, result, leader, pu...         None
# 98   [develop, understand, engin, technolog, leader...         None
# 185  [our, msc, global, logist, suppli, chain, mana...         None
# 346  [the, msc, intern, manag, programm, furnish, s...         None

# %% [markdown]
# ### 2.0.1) Preprocessing the fees column
#
# Moreover, we want the field ```fees``` to collect numeric information. As you will see, you scraped textual information for this attribute in the dataset: sketch whatever method you need (using regex, for example, to find currency symbol) to collect information and, in case of multiple information, retrieve only the highest fees. Finally, once you have collected numerical information, you likely will have different currencies: this can be chaotic, so let chatGPT guide you in the choice and deployment of an API to convert this column to a common currency of your choice (it can be USD, EUR or whatever you want). Ultimately, you will have a ```float``` column renamed ```fees (CHOSEN COMMON CURRENCY)```.

# %%
# !pip install forex-python
# Out:
# Collecting forex-python
#   Downloading forex_python-1.8-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from forex-python) (2.31.0)
# Collecting simplejson (from forex-python)
#   Downloading simplejson-3.19.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->forex-python) (2023.7.22)
# Installing collected packages: simplejson, forex-python
# Successfully installed forex-python-1.8 simplejson-3.19.2

# %%
import pandas as pd
from forex_python.converter import CurrencyRates
#Let's calculate the rate of each currencies compared to EUR to save time in computaton
c = CurrencyRates()
dollar = c.convert('USD', 'EUR', float(1))
pound = c.convert('GBP', 'EUR', float(1))
# Define a function to convert currencies to euros using an API
def convert_to_euros(row):
    if pd.notnull(row['cleaned_fees']):
        c = CurrencyRates()

        # Ensure the "largest_amount" column is treated as a Series

        cleaned_fees_series = pd.Series(row['cleaned_fees'])

        # Replace specific currency symbols with an empty string
        cleaned_fees_series = cleaned_fees_series.replace({'€': '', '$': '', '£': ''}, regex=True)

        # Extract the amount from the modified "cleaned_fees" column
        amount = cleaned_fees_series.str.extract(r'(?P<amount>\d+(\.\d+)?)')['amount'].values[0]

        # Check for the presence of specific currency symbols
        if '€' in row['cleaned_fees']:
            return float(amount)  # No conversion needed for euros
        elif '$' in row['cleaned_fees']:
            return round(float(amount) * dollar, 2)
        elif '£' in row['cleaned_fees']:
            return round(float(amount) * pound, 2)
        else:
            return None  # Handle unknown currencies

    else:
        return None

# Apply the conversion function to the DataFrame
df['fees (EUR)'] = df.apply(convert_to_euros, axis=1)

# %%
df.head()
# Out:
#                                           courseName  \
# 0                      Accounting and Finance - MSc
# 1                                    Addictions MSc
# 2  Accounting, Financial Management and Digital B...
# 3  Agricultural, Environmental and Resource Econo...
# 4  Applied Economics (Banking and Financial Marke...
#
#              universityName  \
# 0      University of Leeds
# 1    King’s College London
# 2    University of Reading
# 3   University of Helsinki
# 4       University of Bath
#
#                                          facultyName             isItFullTime  \
# 0                  Leeds University Business School                Full time
# 1   Institute of Psychiatry, Psychology and Neuro...   Full time & Part time
# 2                            Henley Business School                Full time
# 3           International Masters Degree Programmes                Full time
# 4                         University of Bath Online                Part time
#
#                                          description             startDate  \
# 0   Businesses and governments rely on sound fina...            September
# 1   Join us for an online session for prospective...            September
# 2   Embark on a professional accounting career wi...            September
# 3   Goal of the pro­grammeAre you looking forward...            September
# 4   From political uncertainty to finance and rec...   September, January
#
#                                                 fees modality  \
# 0   UK: £18000 (Total) International: £34750 (Tot...     MSc
# 1   Please see the university website for further...     MSc
# 2   Please see the university website for further...     MSc
# 3   Tuition fee per year (non-EU/EEA students): 1...     MSc
# 4   Cost per 10 credits £722* (10% alumni discoun...     MSc
#
#                            duration        city           country  \
# 0                 1 year full time       Leeds    United Kingdom
# 1                      One year FT      London    United Kingdom
# 2                 1 year full time     Reading    United Kingdom
# 3                          2 years    Helsinki           Finland
# 4   2 years and 6 months full time        Bath    United Kingdom
#
#   adminsitration                                                url  \
# 0     On Campus    https://www.findamasters.com/masters-degrees/...
# 1     On Campus    https://www.findamasters.com/masters-degrees/...
# 2     On Campus    https://www.findamasters.com/masters-degrees/...
# 3     On Campus    https://www.findamasters.com/masters-degrees/...
# 4        Online    https://www.findamasters.com/masters-degrees/...
#
#                                          descr_clean cleaned_fees  fees (EUR)
# 0  [busi, govern, reli, sound, financi, knowledg,...       £34750    39871.49
# 1  [join, us, onlin, session, prospect, student, ...         None         NaN
# 2  [embark, profession, account, career, academ, ...         None         NaN
# 3  [goal, look, forward, futur, expert, agricultu...      15000 €    15000.00
# 4  [from, polit, uncertainti, financ, recruit, de...         £722      828.41

# %% [markdown]
# ### 2.1. Conjunctive query
# For the first version of the search engine, we narrowed our interest to the __description__ of each course. It means that you will evaluate queries only concerning the course's description.

# %%
vocabulary = set()
df.descr_clean.apply(lambda row: [vocabulary.add(word) for word in row])
#creating a set of all words in the corpus
# Out:
# 0       [None, None, None, None, None, None, None, Non...
# 1       [None, None, None, None, None, None, None, Non...
# 2       [None, None, None, None, None, None, None, Non...
# 3       [None, None, None, None, None, None, None, Non...
# 4       [None, None, None, None, None, None, None, Non...
#                               ...
# 5997    [None, None, None, None, None, None, None, Non...
# 5998    [None, None, None, None, None, None, None, Non...
# 5999    [None, None, None, None, None, None, None, Non...
# 6000    [None, None, None, None, None, None, None, Non...
# 6001    [None, None, None, None, None, None, None, Non...
# Name: descr_clean, Length: 6001, dtype: object

# %%
#creating a dataframe with all words in the vocabulary
terms = pd.DataFrame(data=list(vocabulary), columns=['term'])

# %%
from tqdm.notebook import tqdm
#tqdm is used to check the progress
tqdm.pandas()
#creating column inverse that will contain the term with the list of idecies of the documents in which this term is contained
terms['reverse'] = terms.term.progress_apply(lambda item: list(df.loc[df.descr_clean.apply(lambda row: item in row)].index))
# Out:
#   0%|          | 0/8853 [00:00<?, ?it/s]

# %%
#saving this file for further use
terms.to_json('/content/terms')

# %% [markdown]
# ### 2.1.1) Create your index!
#
# Before building the index,
# * Create a file named `vocabulary`, in the format you prefer, that maps each word to an integer (`term_id`).
#
# Then, the first brick of your homework is to create the Inverted Index. It will be a dictionary in this format:
#
# ```
# {
# term_id_1:[document_1, document_2, document_4],
# term_id_2:[document_1, document_3, document_5, document_6],
# ...}
# ```
# where _document\_i_ is the *id* of a document that contains that specific word.
#
# __Hint:__ Since you do not want to compute the inverted index every time you use the Search Engine, it is worth thinking about storing it in a separate file and loading it in memory when needed.

# %%
import pandas as pd
terms = pd.read_json('/content/terms')

# %% [markdown]
# #### 2.1.2) Execute the query
# Given a query input by the user, for example:
#
# ```
# advanced knowledge
# ```
#
# The Search Engine is supposed to return a list of documents.
#
# ##### What documents do we want?
# Since we are dealing with conjunctive queries (AND), each returned document should contain all the words in the query.
# The final output of the query must return, if present, the following information for each of the selected documents:
#
# * `courseName`
# * `universityName`
# * `description`
# * `URL`
#
# __Example Output__ for ```advanced knowledge```: (please note that our examples are made on a small batch of the full dataset)
#
# <p align="center">
# <img src="img/output1.png" width = 1000>
# </p>
#
# If everything works well in this step, you can go to the next point and make your Search Engine more complex and better at answering queries.

# %%
from search_engine_1 import search_engine_1
query = 'advanced knowledge'
search_engine_1_df = search_engine_1(df, terms, query, stemmer, lst_stopwords)

# %%
display(search_engine_1_df[['courseName', 'universityName', 'description', 'url']])
# Out:
#                                              courseName  \
# 0                         Accounting and Finance - MSc
# 1                                       Addictions MSc
# 7                            Analytical Toxicology MSc
# 51                               Civil Engineering MSc
# 77                                     Economics - MSc
# ...                                                 ...
# 5934  Master Sociology – Social and Economic Psychol...
# 5937              Master's course in Cognitive Science
# 5946                              Masters in Economics
# 5953          Master's in Global and European Politics
# 5959                 Masters in Hospitality Management
#
#                                          universityName  \
# 0                                  University of Leeds
# 1                                King’s College London
# 7                                King’s College London
# 51                             University of Greenwich
# 77                                 University of Leeds
# ...                                                 ...
# 5934                             University of Cologne
# 5937                              University of Trento
# 5946                              University of Lisbon
# 5953   European School of Political and Social Scien...
# 5959                       Ecole hotelière de Lausanne
#
#                                             description  \
# 0      Businesses and governments rely on sound fina...
# 1      Join us for an online session for prospective...
# 7      The Analytical Toxicology MSc is a unique stu...
# 51     Meet the future demands of the construction i...
# 77     Our MSc Economics allows you to apply economi...
# ...                                                 ...
# 5934   This programme provides you with:a solid foun...
# 5937   Course overviewThe two-year CIMeC Master’s in...
# 5946   OBJECTIVESThe MSc in Economics aims to provid...
# 5953   Europe and the EU in a changing worldOur inte...
# 5959   With our Master in Hospitality Management, yo...
#
#                                                     url
# 0      https://www.findamasters.com/masters-degrees/...
# 1      https://www.findamasters.com/masters-degrees/...
# 7      https://www.findamasters.com/masters-degrees/...
# 51     https://www.findamasters.com/masters-degrees/...
# 77     https://www.findamasters.com/masters-degrees/...
# ...                                                 ...
# 5934   https://www.findamasters.com/masters-degrees/...
# 5937   https://www.findamasters.com/masters-degrees/...
# 5946   https://www.findamasters.com/masters-degrees/...
# 5953   https://www.findamasters.com/masters-degrees/...
# 5959   https://www.findamasters.com/masters-degrees/...
#
# [468 rows x 4 columns]

# %% [markdown]
# ### 2.2) Conjunctive query & Ranking score
#
# For the second search engine, given a query, we want to get the *top-k* (the choice of *k* it's up to you!) documents related to the query. In particular:
#
# * Find all the documents that contain all the words in the query.
# * Sort them by their similarity with the query.
# * Return in output *k* documents, or all the documents with non-zero similarity with the query when the results are less than _k_. You __must__ use a heap data structure (you can use Python libraries) for maintaining the *top-k* documents.
#
# To solve this task, you must use the *tfIdf* score and the _Cosine similarity_. The field to consider is still the `description`. Let's see how.

# %% [markdown]
# #### 2.2.1) Inverted index
# Your second Inverted Index must be of this format:
#
# ```
# {
# term_id_1:[(document1, tfIdf_{term,document1}), (document2, tfIdf_{term,document2}), (document4, tfIdf_{term,document4}), ...],
# term_id_2:[(document1, tfIdf_{term,document1}), (document3, tfIdf_{term,document3}), (document5, tfIdf_{term,document5}), (document6, tfIdf_{term,document6}), ...],
# ...}
# ```
#
# Practically, for each word, you want the list of documents in which it is contained and the relative *tfIdf* score.
#
# __Tip__: *TfIdf* values are invariant for the query. Due to this reason, you can precalculate and store them accordingly.

# %% [markdown]
# #### 2.2.2) Execute the query
#
# In this new setting, given a query, you get the proper documents (i.e., those containing all the query's words) and sort them according to their similarity to the query. For this purpose, as the scoring function, we will use the Cosine Similarity concerning the *tfIdf* representations of the documents.
#
# Given a query input by the user, for example:
# ```
# advanced knowledge
# ```
# The search engine is supposed to return a list of documents, __ranked__ by their Cosine Similarity to the query entered in the input.
#
# More precisely, the output must contain:
# * `courseName`
# * `universityName`
# * `description`
# * `URL`
# * The similarity score of the documents with respect to the query (float value between 0 and 1)
#
# __Example Output__ for ```advanced knowledge```:
#
# <p align="center">
# <img src="img/output2.png" width = 1000>
# </p>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
#create instance of tfidfVectorizer
tfidf = TfidfVectorizer(input='content', lowercase=False, tokenizer=lambda text: text) # , max_df=0.1
results = tfidf.fit_transform(df.descr_clean)
#from sparse(omitting the values that contain zeros) to dense matrix
result_dense = results.todense()
#creating the dataframe for better understanding and futher use
tfidf_data = pd.DataFrame(result_dense.tolist(), index=df.index, columns=tfidf.get_feature_names_out())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
#pd.set_option('display.max_columns', 7000)
#saving the dataframe so we do not need to calculate the inverse dictionary again
tfidf_data.to_csv('/content/tfidf_data', index=False)

# %%
import search_engine_2_colab
query = 'advanced knowledge'
result = search_engine_2_colab.search_engine_2(df, terms, lst_stopwords, query, K=10)
result
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#                                           courseName  \
# 0             Advancing Practice (PgCert/PgDip/MSc)
# 1      Advanced Structural Engineering MSc (Campus)
# 2     Advanced Clinical Practice MSc, PGDip, PGCert
# 3              International Tourism Management MSc
# 4  Information Systems, Master Programme (60 cred...
# 5   Health, Wellbeing and Sustainable Buildings MSc
# 6          Health and Management MSc (PGCert PGDip)
# 7                       Financial Mathematics - MSc
# 8                      Finance and Investment - MSc
# 9                  Finance and Data Analytics (MSc)
#
#                      universityName  \
# 0         Robert Gordon University
# 1              Aberdeen University
# 2            King’s College London
# 3               Swansea University
# 4              Linnaeus University
# 5        University College London
# 6           University of Brighton
# 7              University of Leeds
# 8              University of Leeds
# 9   Birkbeck, University of London
#
#                                          description  \
# 0   The MSc Advancing Practice course will equip ...
# 1   This advanced programme allows you to explore...
# 2   Advanced Clinical Practice is for experienced...
# 3   Are you interested in a career in tourism whe...
# 4   Information systems offer opportunities for e...
# 5   Register your interest in graduate study at U...
# 6   The Health and Management MSc gives you the o...
# 7   This degree provides you with knowledge of ad...
# 8   Global capital and money markets are rapidly ...
# 9   The financial world’s demand for innovation a...
#
#                                                  url  similarity
# 0   https://www.findamasters.com/masters-degrees/...    0.996266
# 1   https://www.findamasters.com/masters-degrees/...    0.996266
# 2   https://www.findamasters.com/masters-degrees/...    0.996266
# 3   https://www.findamasters.com/masters-degrees/...    0.993414
# 4   https://www.findamasters.com/masters-degrees/...    0.993414
# 5   https://www.findamasters.com/masters-degrees/...    0.993414
# 6   https://www.findamasters.com/masters-degrees/...    0.993414
# 7   https://www.findamasters.com/masters-degrees/...    0.993414
# 8   https://www.findamasters.com/masters-degrees/...    0.993414
# 9   https://www.findamasters.com/masters-degrees/...    0.993414

# %% [markdown]
# ## 3. Define a new score!
#
# Now it's your turn: build a new metric to rank MSc degrees.
#
# Practically:
#
# 1. The user will enter a text query. As a starting point, get the query-related documents by exploiting the search engine of Step 2.1.
# 2. Once you have the documents, you need to sort them according to your new score. In this step, you won't have any more to take into account just the ```description``` field of the documents; you __can__ use also the remaining variables in your dataset (or new possible variables that you can create from the existing ones or scrape again from the original web-pages). You __must__ use a heap data structure (you can use Python libraries) for maintaining the *top-k* documents.
#
# __N.B.:__ You have to define a __scoring function__, not a filter!
#
# The output, must contain:
#
# * `courseName`
# * `universityName`
# * `description`
# * `URL`
# * The  __new__ similarity score of the documents with respect to the query
#
# Are the results you obtain better than with the previous scoring function? **Explain and compare results**.

# %%
# First of all, I listed all columns and decide which column I want to add to my new dataset.
print(df.columns.tolist())
# Out:
# ['courseName', 'universityName', 'facultyName', 'isItFullTime', 'description', 'startDate', 'fees', 'modality', 'duration', 'city', 'country', 'adminsitration', 'url', 'descr_clean', 'cleaned_fees', 'fees (EUR)']

# %%
# Deciding to add facultyName column and I started preprocessing this column.
df.facultyName = df.facultyName.astype(str)
df['facultyName_clean'] = df.facultyName.apply(lambda row: [stemmer.stem(word) for word in nltk.word_tokenize(row) if not word in lst_stopwords and word.isalnum()])

# %%
vocabulary = set()
df.facultyName_clean.apply(lambda row: [vocabulary.add(word) for word in row])
# Out:
# 0             [None, None, None, None]
# 1             [None, None, None, None]
# 2                   [None, None, None]
# 3             [None, None, None, None]
# 4                   [None, None, None]
#                      ...
# 5997    [None, None, None, None, None]
# 5998                      [None, None]
# 5999                            [None]
# 6000                      [None, None]
# 6001                      [None, None]
# Name: facultyName_clean, Length: 6001, dtype: object

# %%
# Creating new dataframe for facultyName with all words in the vocabulary
termsF = pd.DataFrame(data=list(vocabulary), columns=['term'])

# %%
from tqdm.notebook import tqdm
tqdm.pandas()
#Generates a 'reverse' column, pairing each term with the indices of documents where it appears in the 'facultyName_clean' column, with tqdm progress tracking.
termsF['reverse'] = termsF.term.progress_apply(lambda item: list(df.loc[df.facultyName_clean.apply(lambda row: item in row)].index))
# Out:
#   0%|          | 0/8853 [00:00<?, ?it/s]

# %%
#saving DataFrame 'termsF' file for further use
termsF.to_json('/content/termsF')

# %%
# Importing TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
# Creating instance of tfidfVectorizer
tfidf = TfidfVectorizer(input='content', lowercase=False, tokenizer=lambda text: text) # , max_df=0.1
# Applying TfidfVectorizer on the 'facultyName_clean' column of DataFrame 'df'
results = tfidf.fit_transform(df.facultyName_clean)
# Converting the sparse matrix 'results' to a dense matrix
result_dense = results.todense()
# Creating a DataFrame 'tfidf_faculty' for better understanding and further use, with index from 'df' and feature names from TfidfVectorizer
tfidf_faculty = pd.DataFrame(result_dense.tolist(), index=df.index, columns=tfidf.get_feature_names_out())
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/feature_extraction/text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(

# %%
#pd.set_option('display.max_columns', 7000)
#saving DataFrame 'tfidf_faculty' file for further use
tfidf_faculty.to_csv('/content/tfidf_faculty', index=False)

# %%
# Importing the 'search_engine_3' module for a custom search engine implementation
from search_engine_3 import search_engine_3
query = 'advanced knowledge'
result = search_engine_3(df, terms, termsF, lst_stopwords, query, K=10)
# The 'result' variable now holds the top search results based on the provided query.
result
# Out:
#                                        facultyName  \
# 0   Online, Flexible and Professional Development
# 1                                Masters Programs
# 2               Advanced Academic Programs Online
# 3               Advanced Academic Programs Online
# 4               Advanced Academic Programs Online
# 5               Advanced Academic Programs Online
# 6               Advanced Academic Programs Online
# 7               Advanced Academic Programs Online
# 8               Advanced Academic Programs Online
# 9                      Advanced Clinical Practice
#
#                         universityName  \
# 0   Atlantic Technological University
# 1                 University of Tampa
# 2            Johns Hopkins University
# 3            Johns Hopkins University
# 4            Johns Hopkins University
# 5            Johns Hopkins University
# 6            Johns Hopkins University
# 7            Johns Hopkins University
# 8            Johns Hopkins University
# 9            Brunel University London
#
#                                          description  \
# 0   In ATU Mayo our commitment to postgraduate pa...
# 1   UT's M.S. in instructional design and technol...
# 2   Experience an Innovative Education in Genomic...
# 3   Enact Sustainable Policies for Safeguarding t...
# 4   Promote Access to Safe, Healthy FoodBecome qu...
# 5   Experience a Johns Hopkins Education in a Con...
# 6   Help Develop Advancements in Life Sciences, T...
# 7   Build Expertise in Biology, Programming, and ...
# 8   Earn an Empowering Johns Hopkins Education in...
# 9   The Advanced Clinical Practice Apprenticeship...
#
#                                                  url  similarity
# 0   https://www.findamasters.com/masters-degrees/...    0.203888
# 1   https://www.findamasters.com/masters-degrees/...    0.203888
# 2   https://www.findamasters.com/masters-degrees/...    0.203888
# 3   https://www.findamasters.com/masters-degrees/...    0.203888
# 4   https://www.findamasters.com/masters-degrees/...    0.203888
# 5   https://www.findamasters.com/masters-degrees/...    0.203888
# 6   https://www.findamasters.com/masters-degrees/...    0.203888
# 7   https://www.findamasters.com/masters-degrees/...    0.203888
# 8   https://www.findamasters.com/masters-degrees/...    0.203888
# 9   https://www.findamasters.com/masters-degrees/...    0.203888

# %% [markdown]
# # ***Conclusion***
#
# **Cosine Similarity**
#
# Cosine Similarity yields varied scores, reflecting nuanced differences between entries. Higher scores, like 0.996266, indicate a strong match between the query and related courses. The method's flexibility in the -1 to 1 range allows for a more precise evaluation, where higher scores signify heightened similarity. This adaptability and sensitivity make Cosine Similarity a versatile and informative measure for comparing textual data, capturing subtle distinctions with greater precision.
#
# **Euclidean Distance**
#
# The Euclidean Distance results reveal a uniformity in similarity scores across all entries, with each assigned a value of 0.203888. This homogeneity suggests a limitation in the Euclidean distance metric's ability to discriminate effectively between different entries. The observed lack of variability in scores indicates that the method struggles to capture nuanced differences in the data, potentially due to shortcomings in the feature representation or the choice of distance metric.
#
#
# Since it provides varying and meaningful similarity scores and can distinguish between entries more effectively than Euclidean Distance, Cosine Similarity appears more effective. Cosine Similarity seems to be more suitable for capturing the similarity between text-based entries in this context, offering a more nuanced and informative measure compared to the Euclidean Distance.

# %% [markdown]
# ## 4. Visualizing the most relevant MSc degrees
#
# Using maps can help people understand how far one university is from another so they can plan their academic careers more adequately. Here, we challenge you to show a map of the courses found with the score defined in point 3. You should be able to identify at least the *city* and *country* for each MSc degree. You can find some ideas on how to create maps in Python [here](https://plotly.com/python/maps/) and [here](https://towardsdatascience.com/visualizing-geospatial-data-in-python-e070374fe621) but you will maybe need further information for a proper visualization, like coordinates (latitude and longitude). You can retrieve this data using various tools:
#
# 1. [Here](https://medium.com/@manilwagle/geocoding-the-world-using-google-api-and-python-1f6b6fb6ca48) you can find a helpful tutorial on how to encode geo-informations using Google API in Python (this tool can also be used in [Google Sheets](https://handsondataviz.org/geocode.html))
# 2. You can collect a list of unique places in the format (City, Country) and ask chatGPT (or, as usual, any other LLM chatbot) to provide you with a list of corresponding representative coordinates
# 3. Explore and find the best solution for your case!
#
# Once you defined your visualization strategy, include a way to encode fees in your charts. The map should show (with a proper legend) different courses and associated taxation: the user wants a glimpse not only of how far he will need to move but also of how much it will cost him!

# %% [markdown]
# ## 5. BONUS: More complex search engine
#
# __IMPORTANT:__ This is a bonus step, so it's <ins>not mandatory</ins>. You can get the maximum score also without doing this. We will take this into account, **only if** the rest of the homework has been completed.
#
# For the Bonus part, we want to ask you more sophisticated search engine. Here we want to let users issue more complex queries. The options of this new search engine are:
# 1. Give the possibility to specify queries for the following features (the user should have the option to issue __none or all of them__):
# * `courseName`
# * `universityName`
# * `universityCity`
# 2. Specify a range for the __fees__ to retrieve only MSc whose taxation is in that range.
# 3. Specify a list of __countries__ which the search engine should only return the courses taking place in city within those countries.
# 4. Filter based on the courses that have already started.
# 5. Filter based on the presence of online modality.
#
# __Note 1__: You should be aware that you should give the user the possibility <ins>to select any</ins> of the abovementioned options. How should the user use the options? We will accept __any manual__ that you provide to the user.
#
# __Note 2__: As you may have realized from __1st option__, you need to build <ins>inverted indexes</ins> for those values and return all of the documents that have the similarity <ins>more than 0</ins> concerning the given queries. Choose a __logical__ way to aggregate the similarity coming from each of them and explain your idea in detail.
#
# __Note 3__: The options <ins>other than 1st</ins> one can be considered as __filtering criteria__ so the retrieved documents <ins>must respect all</ins> of those filters.
#
# The output must contain the following information about the places:
#
# * `courseName`
# * `universityName`
# * `url`

# %% [markdown]
# ## 6. Command Line Question
#
# As done in the previous assignment, we encourage using the command as a feature that Data Scientists must master.
#
# Note: To answer the question in this section, you must strictly use command line tools. We will reject any other method of response. The final script must be placed in CommandLine.sh.
#
# First, take the course_i.tsv files you created in point 1 and merge them using Linux commands (Hint: make sure that the first row containing the column names appears only once).
#
# Now that you have your merged file named merged_courses.tsv, use Linux commands to answer the following questions:
# - Which country offers the most Master's Degrees? Which city?
# - How many colleges offer Part-Time education?
# - Print the percentage of courses in Engineering (the word "Engineer" is contained in the course's name).
#
# __Important note:__ You may work on this question in any environment (AWS, your PC command line, Jupyter notebook, etc.), but the final script must be placed in CommandLine.sh, which must be executable. Please run the script and include a __screenshot__ of the <ins>output</ins> in the notebook for evaluation.

# %% [markdown]
# ## 7. Algorithmic Question
# Leonardo is an intern at a company. He is paid based on the total number of hours he has worked. They agreed __d__ days ago that Leonardo could not work less than $minTime_i$ or more than $maxTime_i$ hours per <ins>i-th</ins> day. Furthermore, he was warned by HR that on his last day at the company, he should provide a detailed report on how many hours he worked <ins>each day</ins> for the previous d days.
#
# Today is the day Leonardo should report to HR, but the problem is that he <ins>didn't</ins> account for how many hours he put in for each day, so he only has the __total sum of the hours__ ($sumHours$) he put in total in these d days. He believes that if he creates a report in which each number $dayHours_i$ corresponds to the __total hours he worked on the i-th day__ while satisfying the HR limitations and the total sum of all $dayHours_i$ equals $sumHours$, he would be fine.
#
# He cannot create such a report independently and requests your assistance. He will give you the number of days $d$, total hours spent $sumHours$, and the HR limitations for each day $i$, and he wants you to assist him in determining whether it is possible to create such a fake report. If that is possible, make such a report.
#
# **Input**
#
# The first line of input contains two integers __d__, $sumHours$ - the number of days Leonardo worked there and the total number of hours he worked for the company. Each of the following __d__ lines contains two integer numbers $minTime_i$ and $maxTime_i$ - the minimum and maximum hours he can work on the $i_{th}$ day.
#
# **Output**
#
# If such a report cannot be generated, print 'NO' in one output line. If such a report is possible, print 'YES' in the output and d numbers - the number of hours Leonardo spent each day - in the second line. If more than one solution exists, print any of them.
#
# __Input 1__
# ```
# 2 5
# 0 1
# 3 5
# ```
# __Output 1__
# ```
# YES
# 1 4
# ```
# ---
# __Input 2__
# ```
# 1 1
# 5 6
# ```
# __Output 2__
# ```
# NO
# ```
#
# 1. Implement a code to solve the above mentioned problem.

# %%
def report():
    # 'value'    --> is a list that contains the total number of days worked and the total number of hours worked
    # 'remaning' --> is a list used to store the condition 'YES' or 'NO' and
    #                the remaining hours of work that are not assign to a specific day
    # 'i'        --> is an index
    value, remaning, i = list(map(int, input().split())), ["", 0], 0

    # We create a list of lists composed of a set of values containing the minimum hours worked,
    # the maximum hours worked and the hours actually worked initialized to the minimum value
    # Every item in this list of list is a different day
    days = [[minimo, massimo, minimo] for _ in range(value[0]) for minimo, massimo in [map(int, input().split())]]

    # Check if the sum of maximum possible working hours for all days is greater or equal to
    # the total number of hours worked and if the sum of minumum working hours is lower than
    # the total of hours worked
    # --> if the condition is TRUE than we can generate a report with the desired features
    #     --> we set the values of 'remaning' equal to 'YES' and equal to the the remaining hours of work
    #         that are not assigned to a specific day
    # --> if the condition is FALSE than we can not generate a report with the desired features
    #     --> we set the values of 'remaning' equal to 'NO' and 0
    remaning = ["YES", (value[1] - sum(item[0] for item in days))] if (sum(item[1] for item in days) >= value[1]) & (sum(item[1] for item in days) <= value[1]) else ["NO", 0]

    # If we can not generate a report with the desired features then we return 'NO'
    if remaning[0] == "NO": return remaning[0]

    # If we get to this point it is implied that we can generate a report with the desired features
    # As long as the number of hours that are not assigned is greater than 0 it means that in some days
    #    we have worked more than the minimum number of hours
    while remaning[1] > 0:
        # Update the working hours for the current day to the maximum
        # We reduce the number of hours that we have not yet assigned
        #    by the number of hours we have just added to the i-th day (maximum-minimum)
        # We add 1 to the index
        days[i][2], remaning[1], i = days[i][1], remaning[1] - (days[i][1] - days[i][0]), i + 1

    # If there is a negative remaining of hours that we have not yet assigned
    #    it means that we added too many hours to the last day set to the maximum hours
    # So we remove this excess from the last day
    # --> we use the + operator because the remaining number is negative
    if remaning[1] < 0:
        days[i - 1][2] = days[i - 1][2] + remaning[1]

    # Return the result in the specified format
    return f'{remaning[0]}\n{" ".join(map(str, list(zip(*days))[2]))}'

# Print the result of the report-function
print(report())

# %% [markdown]
# 2. What is the __time complexity__ (the Big O notation) of your solution? Please provide a <ins>detailed explanation</ins> of how you calculated the time complexity.
#
# 3. Ask ChatGPT or any other LLM chatbot tool to check your code's time complexity (the Big O notation). Compare your answer to theirs. Do you believe this is correct? If the <ins>two differ</ins>, which one is right? (why?)
#
# 4. What do you think of the __optimality__ of your code? Do you believe it is optimal? Can you improve? Please <ins>elaborate</ins> on your response.
